# %%
import pandas as pd
import pymongo
from pymongo import MongoClient
from bson.decimal128 import Decimal128
from urllib.parse import quote_plus

# %%
'''username = quote_plus('arjun07cr')
password = quote_plus('arjun07cr')'''

connection_string = "mongodb+srv://arjun07cr:arjun07cr@arjun.nt7lb25.mongodb.net/"

client = MongoClient(connection_string)

db = client.get_database("sample_airbnb")
col = db["listingsAndReviews"]
ab = col.find()
data = []

for i in ab:
    data.append({'country_code':i['address']['country_code'],
                 'location_type':i['address']['location']['type'],
                 'longitude':i['address']['location']['coordinates']['0']
                 })
              
            
    
    df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 16
#      11 data = []
#      13 for i in ab:
#      14     data.append({'country_code':i['address']['country_code'],
#      15                  'location_type':i['address']['location']['type'],
# ---> 16                  'longitude':i['address']['location']['coordinates']['0']
#      17                  })
#      21     df = pd.DataFrame(data)
#
# TypeError: list indices must be integers or slices, not str

# %%
df
# Out:
#       host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                       True                    3                          3
# 1                      False                    1                          1
# 2                      False                   18                         18
# 3                       True                    1                          1
# 4                      False                    1                          1
# ...                      ...                  ...                        ...
# 5550                   False                    8                          8
# 5551                   False                    2                          2
# 5552                    True                    3                          3
# 5553                    True                   58                         58
# 5554                    True                   58                         58
#
#                                      host_verifications  \
# 0     [email, phone, reviews, jumio, offline_governm...
# 1                              [email, phone, facebook]
# 2                          [email, phone, reviews, kba]
# 3                          [email, phone, reviews, kba]
# 4                  [email, phone, jumio, government_id]
# ...                                                 ...
# 5550  [email, phone, reviews, offline_government_id,...
# 5551                                     [email, phone]
# 5552  [email, phone, reviews, jumio, government_id, ...
# 5553           [email, phone, reviews, kba, work_email]
# 5554           [email, phone, reviews, kba, work_email]
#
#                                       street           suburb  \
# 0                     Porto, Porto, Portugal
# 1     Rio de Janeiro, Rio de Janeiro, Brazil  Jardim Botânico
# 2                Honolulu, HI, United States            Oʻahu
# 3                Brooklyn, NY, United States         Brooklyn
# 4     Rio de Janeiro, Rio de Janeiro, Brazil            Lagoa
# ...                                      ...              ...
# 5550                  Porto, Porto, Portugal
# 5551               Kadıköy, İstanbul, Turkey             Moda
# 5552  Rio de Janeiro, Rio de Janeiro, Brazil       Copacabana
# 5553              Lahaina, HI, United States             Maui
# 5554              Lahaina, HI, United States          Lahaina
#
#                                         government_area
# 0     Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...
# 1                                       Jardim Botânico
# 2                                  Primary Urban Center
# 3                                              Bushwick
# 4                                                 Lagoa
# ...                                                 ...
# 5550  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...
# 5551                                            Kadikoy
# 5552                                         Copacabana
# 5553                                            Lahaina
# 5554                                            Lahaina
#
# [5555 rows x 7 columns]

# %%
'''   'Name': i['name'],
                 'listing_url':i['listing_url'],
                 'property_type':i['property_type'],
                 'room_type':i['room_type'],
                 'bed_type':i['bed_type'],
                 'minimum_nights':i['minimum_nights'],
                 'maximum_nights':i['maximum_nights'],
                'cancellation_policy':i['cancellation_policy'],
                'accommodates':i['accommodates'],
                'bedrooms':i['bedrooms'],
                'beds':i['beds'],
                'number_of_reviews':i['number_of_reviews'],
                'bathrooms':i['bathrooms'],
                'price':i['price'],
                'extra_people':i['extra_people'],
                'guests_included':i['guests_included'],
                'images':i['images']['picture_url']
                'review_scores':i['review_scores']['review_scores_rating'],
                'cleaning_fee':i['cleaning_fee'],
                'host_id':i['host']['host_id'],
                'host_url':i['host']['host_url'],
                'host_name':i['host']['host_name'],
                'host_location':i['host']['host_location'],
                'host_response':i['host']['host_response_time'],
                'host_thumbnail_url':i['host']['host_thumbnail_url'],
                'host_picture_url':i['host']['host_picture_url'],
                'host_neighbourhood':i['host']['host_neighbourhood'],
                'host_response_rate':i['host']['host_response_rate'],
                'host_is_superhost':i['host']['host_is_superhost'],
                'host_has_profile_pic':i['host']['host_has_profile_pic'],
                'host_identity_verified':i['host']['host_identity_verified'],
                'host_listings_count':i['host']['host_listings_count'],
                'host_total_listings_count':i['host']['host_total_listings_count'],
                'host_verifications':i['host']['host_verifications'],
                'street':i['address']['street'],
                'suburb':i['address']['suburb'],
                'government_area':i['address']['government_area'],
                'market':i['address']['market'],
                'country':i['address']['country'],
                'country_code':i['address']['country_code'],
                'location_type':i['address']['location']['type'],
                'longitude':i['address']['location']['coordinates']['0'],
                'latitude':i['address']['location']['coordinates']['1'],
                'is_location_exact':i['address']['location']['coordinates']['is_location_exact'],
                'availability_30':i['availability']['availability_30'],
                'availability_60':i['availability']['availability_60'],
                'availability_90':i['availability']['availability_90'],
                'availability_365':i['availability']['availability_365'],
                'amenities':i['amenities']}) '''

# %%
                 'ID':i['_id'],
                 'Name': i['name'],
                 'listing_url':i['listing_url'],
                 'property_type':i['property_type'],
                 'room_type':i['room_type'],
                 'bed_type':i['bed_type'],
                 'minimum_nights':i['minimum_nights'],
                 'maximum_nights':i['maximum_nights'],
                 'cancellation_policy':i['cancellation_policy'],
                 'accommodates':i['accommodates'],
                 'bedrooms':i.get('bedrooms',0),
                 'beds':i.get('beds',0),
                 'number_of_reviews':i['number_of_reviews'],
                 'bathrooms':i.get('bathrooms',0),
                 'price':i['price'],
                 'extra_people':i['extra_people'],
                 'guests_included':i['guests_included'],
                 'images':i['images']['picture_url'],
                 'review_scores':i['review_scores'].get('review_scores_rating'),
                 'cleaning_fee':i.get('cleaning_fee',0),
                 'host_id':i['host']['host_id'],
                 'host_url':i['host']['host_url'],
                 'host_name':i['host']['host_name'],
                 'host_location':i['host']['host_location'],
                 'host_response':i['host'].get('host_response_time'),
                 'host_thumbnail_url':i['host']['host_thumbnail_url'],
                 'host_picture_url':i['host']['host_picture_url'],
                 'host_neighbourhood':i['host']['host_neighbourhood'],
                 'host_response_rate':i['host'].get('host_response_rate'),
                 'host_is_superhost':i['host']['host_is_superhost'],
                 'host_has_profile_pic':i['host']['host_has_profile_pic'],
                 'host_identity_verified':i['host']['host_identity_verified'],
                 'host_listings_count':i['host']['host_listings_count'],
                 'host_total_listings_count':i['host']['host_total_listings_count'],
                 'host_verifications':i['host']['host_verifications'],
                 'street':i['address']['street'],
                 'suburb':i['address']['suburb'],
                 'government_area':i['address']['government_area'],
                 'market':i['address']['market'],
                 'country':i['address']['country']

# %%
connection_string = "mongodb+srv://arjun07cr:arjun07cr@arjun.nt7lb25.mongodb.net/"

client = MongoClient(connection_string)

db = client["sample_airbnb"]
col = db["listingsAndReviews"]
ab = col.find().limit(10)
df = pd.DataFrame(list(ab))
print(ab)

                'host_id':i['host']['host_id'],
                'host_url':i['host']['host_url'],
                'host_name':i['host']['host_name'],
                'host_location':i['host']['host_location'],
                'host_response':i['host']['host_response_time'],
                'host_thumbnail_url':i['host']['host_thumbnail_url'],
                'host_picture_url':i['host']['host_picture_url'],
                'host_neighbourhood':i['host']['host_neighbourhood'],
                'host_response_rate':i['host']['host_response_rate'],
                'host_is_superhost':i['host']['host_is_superhost'],
                'host_has_profile_pic':i['host']['host_has_profile_pic'],
                'host_identity_verified':i['host']['host_identity_verified'],
                'host_listings_count':i['host']['host_listings_count'],
                'host_total_listings_count':i['host']['host_total_listings_count'],
                'host_verifications':i['host']['host_verifications'],
                'street':i['address']['street'],
                'suburb':i['address']['suburb'],
                'government_area':i['address']['government_area'],
                'market':i['address']['market'],
                'country':i['address']['country'],
                'country_code':i['address']['country_code'],
                'location_type':i['address']['location']['type'],
                'longitude':i['address']['location']['coordinates']['0'],
                'latitude':i['address']['location']['coordinates']['1'],
                'is_location_exact':i['address']['location']['coordinates']['is_location_exact'],
                'availability_30':i['availability']['availability_30'],
                'availability_60':i['availability']['availability_60'],
                'availability_90':i['availability']['availability_90'],
                'availability_365':i['availability']['availability_365'],
                'amenities':i['amenities']
# Out:
# <pymongo.cursor.Cursor object at 0x0000016B218F3320>
